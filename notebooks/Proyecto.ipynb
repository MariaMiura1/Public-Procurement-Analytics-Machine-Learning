# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/mariamiura/procurement-project/.venv/lib/python3.9/site-packages (2.3.3)
# Requirement already satisfied: tzdata>=2022.7 in /Users/mariamiura/procurement-project/.venv/lib/python3.9/site-packages (from pandas) (2025.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mariamiura/procurement-project/.venv/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.22.4 in /Users/mariamiura/procurement-project/.venv/lib/python3.9/site-packages (from pandas) (2.0.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/mariamiura/procurement-project/.venv/lib/python3.9/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/mariamiura/procurement-project/.venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Users/mariamiura/procurement-project/.venv/bin/python3 -m pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", 200)
pd.set_option("display.width", 200)

PATH_TED = "../data_raw/export_CFC_2018_2023.csv"
PATH_PCSP = "../data_raw/e05188501-perfiles-de-contratante-de-los-organos-de-contratacion-alojados-en-la-plataforma-de-contratacion-del-sector-publico.csv"

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", 200)
pd.set_option("display.width", 200)

PATH_TED = "../data_raw/export_CFC_2018_2023.csv"
PATH_PCSP = "../data_raw/e05188501-perfiles-de-contratante-de-los-organos-de-contratacion-alojados-en-la-plataforma-de-contratacion-del-sector-publico.csv"

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", 200)
pd.set_option("display.width", 200)

PATH_TED = "../data_raw/export_CFC_2018_2023.csv"
PATH_PCSP = "../data_raw/e05188501-perfiles-de-contratante-de-los-organos-de-contratacion-alojados-en-la-plataforma-de-contratacion-del-sector-publico.csv"

# %%
ted_head = pd.read_csv(PATH_TED, nrows=5, low_memory=False)
pcsp_head = pd.read_csv(PATH_PCSP, nrows=5, low_memory=False)

print("TED shape (head):", ted_head.shape)
print("PCSP shape (head):", pcsp_head.shape)

ted_head.head()
# Out:
# TED shape (head): (5, 64)
# PCSP shape (head): (1, 20)
#    ID_NOTICE_CN                                     TED_NOTICE_URL  YEAR  ID_TYPE DT_DISPATCH XSD_VERSION  CANCELLED  CORRECTIONS  FUTURE_CAN_ID  FUTURE_CAN_ID_ESTIMATED B_MULTIPLE_CAE  \
# 0         20181  ted.europa.eu/udl?uri=TED:NOTICE:1-2018:TEXT:E...  2018        2    22/12/17     R209.S2          0            1     2021265222                        0              N
# 1         20181  ted.europa.eu/udl?uri=TED:NOTICE:1-2018:TEXT:E...  2018        2    22/12/17     R209.S2          0            1     2022329163                        0              N
# 2         20182  ted.europa.eu/udl?uri=TED:NOTICE:2-2018:TEXT:E...  2018        2    22/12/17     R209.S2          0            1     2018489569                        0              N
# 3         20182  ted.europa.eu/udl?uri=TED:NOTICE:2-2018:TEXT:E...  2018        2    22/12/17     R209.S2          0            1     2018489569                        0              N
# 4         20182  ted.europa.eu/udl?uri=TED:NOTICE:2-2018:TEXT:E...  2018        2    22/12/17     R209.S2          0            1     2018489569                        0              N
#
#                                             CAE_NAME  CAE_NATIONALID                                 CAE_ADDRESS    CAE_TOWN     CAE_POSTAL_CODE ISO_COUNTRY_CODE B_MULTIPLE_COUNTRY  \
# 0  Innovative Medicines Initiative 2 Joint Undert...             NaN      IMI2 JU — TO 56 1049 Brussels; Belgium    Brussels                1060               BE                  N
# 1  Innovative Medicines Initiative 2 Joint Undert...             NaN      IMI2 JU — TO 56 1049 Brussels; Belgium    Brussels                1060               BE                  N
# 2  Translation Centre for the Bodies of the Europ...             NaN  Bâtiment Drosbach 12E, rue Guillaume Kroll  Luxembourg  L-1882 -Luxembourg               LU                  N
# 3  Translation Centre for the Bodies of the Europ...             NaN  Bâtiment Drosbach 12E, rue Guillaume Kroll  Luxembourg  L-1882 -Luxembourg               LU                  N
# 4  Translation Centre for the Bodies of the Europ...             NaN  Bâtiment Drosbach 12E, rue Guillaume Kroll  Luxembourg  L-1882 -Luxembourg               LU                  N
#
#    ISO_COUNTRY_CODE_ALL  CAE_TYPE EU_INST_CODE MAIN_ACTIVITY B_ON_BEHALF B_INVOLVES_JOINT_PROCUREMENT B_AWARDED_BY_CENTRAL_BODY TYPE_OF_CONTRACT TAL_LOCATION_NUTS B_FRA_AGREEMENT  FRA_ESTIMATED  \
# 0                   NaN         5           AG        Health           Y                            Y                         N                S              BE10               Y            NaN
# 1                   NaN         5           AG        Health           Y                            Y                         N                S              BE10               Y            NaN
# 2                   NaN         5           AG         Other           Y                            N                         Y                S             LU000               Y            NaN
# 3                   NaN         5           AG         Other           Y                            N                         Y                S             LU000               Y            NaN
# 4                   NaN         5           AG         Other           Y                            N                         Y                S             LU000               Y            NaN
#
#   B_FRA_SINGLE_OPERATOR  FRA_NUMBER_OPERATORS  FRA_NUMBER_MAX_OPERATORS B_DYN_PURCH_SYST       CPV  ID_LOT  ADDITIONAL_CPVS B_GPA  LOTS_NUMBER  LOTS_SUBMISSION B_VARIANTS  VALUE_EURO  \
# 0                     N                     3                         3                N  79200000     NaN         79210000     N            1              NaN          N           1
# 1                     N                     3                         3                N  79200000     NaN         79210000     N            1              NaN          N           1
# 2                     N                    15                        15                N  79530000     1.0         79530000     N           23              NaN          N     2400000
# 3                     N                    15                        15                N  79530000    10.0         79530000     N           23              NaN          N     2400000
# 4                     N                    15                        15                N  79530000    11.0         79530000     N           23              NaN          N     2400000
#
#    VALUE_EURO_FIN_1  VALUE_EURO_FIN_2 B_OPTIONS B_EU_FUNDS B_RENEWALS  DURATION  CONTRACT_START  CONTRACT_COMPLETION TOP_TYPE  B_ACCELERATED  ENV_OPERATORS  ENV_MIN_OPERATORS  ENV_MAX_OPERATORS  \
# 0                 1                 1         N          Y          Y        36             NaN                  NaN      OPE            NaN            NaN                NaN                NaN
# 1                 1                 1         N          Y          Y        36             NaN                  NaN      OPE            NaN            NaN                NaN                NaN
# 2           2400000           2400000         N          N          Y        12             NaN                  NaN      OPE            NaN            NaN                NaN                NaN
# 3           2400000           2400000         N          N          Y        12             NaN                  NaN      OPE            NaN            NaN                NaN                NaN
# 4           2400000           2400000         N          N          Y        12             NaN                  NaN      OPE            NaN            NaN                NaN                NaN
#
#    CRIT_CODE  CRIT_PRICE_WEIGHT  CRIT_CRITERIA  CRIT_WEIGHTS B_ELECTRONIC_AUCTION DT_APPLICATIONS  B_LANGUAGE_ANY_EC                             ADMIN_LANGUAGES_TENDER  ADMIN_OTHER_LANGUAGES_TENDER  \
# 0        NaN                NaN            NaN           NaN                    N        05/02/18                NaN  BG|CS|DA|DE|EL|EN|ES|ET|FI|FR|GA|HR|HU|IT|LT|L...                           NaN
# 1        NaN                NaN            NaN           NaN                    N        05/02/18                NaN  BG|CS|DA|DE|EL|EN|ES|ET|FI|FR|GA|HR|HU|IT|LT|L...                           NaN
# 2        NaN                NaN            NaN           NaN                    N        13/02/18                NaN  EN|BG|DA|DE|EL|ET|FI|FR|GA|HR|HU|IT|LV|LT|MT|N...                           NaN
# 3        NaN                NaN            NaN           NaN                    N        13/02/18                NaN  EN|BG|DA|DE|EL|ET|FI|FR|GA|HR|HU|IT|LV|LT|MT|N...                           NaN
# 4        NaN                NaN            NaN           NaN                    N        13/02/18                NaN  EN|BG|DA|DE|EL|ET|FI|FR|GA|HR|HU|IT|LV|LT|MT|N...                           NaN
#
#   B_RECURRENT_PROCUREMENT
# 0                       N
# 1                       N
# 2                       N
# 3                       N
# 4                       N

# %%
pcsp_head.head()
# Out:
#                                                  URL TIPO DE ENTIDAD  IDENTIFICADOR                                             TÍTULO                                        DESCRIPCIÓN  \
# 0  https://datos.gob.es/catalogo/e05188501-perfil...         dataset            NaN  [es]Perfiles de contratante de los órganos de ...  [es]Información sobre las licitaciones que se ...
#
#                   TEMÁTICAS                                          ETIQUETAS  FECHA DE CREACIÓN  FECHA DE ÚLTIMA MODIFICACIÓN                     FRECUENCIA DE ACTUALIZACIÓN  \
# 0  Hacienda//Sector público  [es]Contrataciones y licitaciones//Dirección G...                NaN                           NaN  [TYPE]http://www.w3.org/2006/time#days[VALUE]1
#
#                                              IDIOMAS                         ÓRGANO PUBLICADOR                                 CONDICIONES DE USO COBERTURA GEOGRÁFICA  COBERTURA TEMPORAL  \
# 0  http://publications.europa.eu/resource/authori...  Ministerio de Hacienda y Función Pública  https://www.hacienda.gob.es/es-ES/Paginas/Avis...               España                 NaN
#
#    VIGENCIA DEL RECURSO  RECURSOS RELACIONADOS  NORMATIVA                                     DISTRIBUCIONES  URL DE ACCESO
# 0                   NaN                    NaN        NaN  [TITLE_es]Perfiles de contratante de los órgan...            NaN

# %%
print("TED columns:\n", ted_head.columns.tolist())
print("\nPCSP columns:\n", pcsp_head.columns.tolist())
# Out:
# TED columns:
#  ['ID_NOTICE_CN', 'TED_NOTICE_URL', 'YEAR', 'ID_TYPE', 'DT_DISPATCH', 'XSD_VERSION', 'CANCELLED', 'CORRECTIONS', 'FUTURE_CAN_ID', 'FUTURE_CAN_ID_ESTIMATED', 'B_MULTIPLE_CAE', 'CAE_NAME', 'CAE_NATIONALID', 'CAE_ADDRESS', 'CAE_TOWN', 'CAE_POSTAL_CODE', 'ISO_COUNTRY_CODE', 'B_MULTIPLE_COUNTRY', 'ISO_COUNTRY_CODE_ALL', 'CAE_TYPE', 'EU_INST_CODE', 'MAIN_ACTIVITY', 'B_ON_BEHALF', 'B_INVOLVES_JOINT_PROCUREMENT', 'B_AWARDED_BY_CENTRAL_BODY', 'TYPE_OF_CONTRACT', 'TAL_LOCATION_NUTS', 'B_FRA_AGREEMENT', 'FRA_ESTIMATED', 'B_FRA_SINGLE_OPERATOR', 'FRA_NUMBER_OPERATORS', 'FRA_NUMBER_MAX_OPERATORS', 'B_DYN_PURCH_SYST', 'CPV', 'ID_LOT', 'ADDITIONAL_CPVS', 'B_GPA', 'LOTS_NUMBER', 'LOTS_SUBMISSION', 'B_VARIANTS', 'VALUE_EURO', 'VALUE_EURO_FIN_1', 'VALUE_EURO_FIN_2', 'B_OPTIONS', 'B_EU_FUNDS', 'B_RENEWALS', 'DURATION', 'CONTRACT_START', 'CONTRACT_COMPLETION', 'TOP_TYPE', 'B_ACCELERATED', 'ENV_OPERATORS', 'ENV_MIN_OPERATORS', 'ENV_MAX_OPERATORS', 'CRIT_CODE', 'CRIT_PRICE_WEIGHT', 'CRIT_CRITERIA', 'CRIT_WEIGHTS', 'B_ELECTRONIC_AUCTION', 'DT_APPLICATIONS', 'B_LANGUAGE_ANY_EC', 'ADMIN_LANGUAGES_TENDER', 'ADMIN_OTHER_LANGUAGES_TENDER', 'B_RECURRENT_PROCUREMENT']
#
# PCSP columns:
#  ['URL', 'TIPO DE ENTIDAD', 'IDENTIFICADOR', 'TÍTULO', 'DESCRIPCIÓN', 'TEMÁTICAS', 'ETIQUETAS', 'FECHA DE CREACIÓN', 'FECHA DE ÚLTIMA MODIFICACIÓN', 'FRECUENCIA DE ACTUALIZACIÓN', 'IDIOMAS', 'ÓRGANO PUBLICADOR', 'CONDICIONES DE USO', 'COBERTURA GEOGRÁFICA', 'COBERTURA TEMPORAL', 'VIGENCIA DEL RECURSO', 'RECURSOS RELACIONADOS', 'NORMATIVA', 'DISTRIBUCIONES', 'URL DE ACCESO']

# %%
chunks = pd.read_csv(
    PATH_TED,
    usecols=[
        "ISO_COUNTRY_CODE",
        "CPV",
        "TYPE_OF_CONTRACT",
        "VALUE_EURO",
        "DT_DISPATCH",
        "CRIT_CODE",
        "LOTS_NUMBER"
    ],
    chunksize=300_000,
    low_memory=False
)

ted_es = []

for ch in chunks:
    es = ch[ch["ISO_COUNTRY_CODE"] == "ES"]
    if len(es):
        ted_es.append(es)

ted_es = pd.concat(ted_es, ignore_index=True)
ted_es.shape
# Out:
# (364150, 7)

# %%
# Importes
ted_es["VALUE_EURO"].describe(percentiles=[.5, .9, .99])

# CPV (primeros 2 dígitos)
ted_es["CPV_GROUP"] = ted_es["CPV"].astype(str).str[:2]
ted_es["CPV_GROUP"].value_counts().head(10)

# Tipo de contrato
ted_es["TYPE_OF_CONTRACT"].value_counts()
# Out:
# TYPE_OF_CONTRACT
# S    193697
# U    163729
# W      6723
# Name: count, dtype: int64

# %%
import os
os.makedirs("../data", exist_ok=True)

# %%
ted_es_sample = ted_es.sample(10_000, random_state=42)
ted_es_sample.to_csv("../data/sample_ted_es.csv", index=False)

# %%
print(ted_es.shape)
ted_es.head()
# Out:
# (364150, 8)
#   DT_DISPATCH ISO_COUNTRY_CODE TYPE_OF_CONTRACT         CPV  LOTS_NUMBER   VALUE_EURO CRIT_CODE CPV_GROUP
# 0    29/12/21               ES                W  45215140.0          1.0  14331693.71       NaN        45
# 1    28/12/22               ES                S  72200000.0          1.0    595041.32       NaN        72
# 2    29/12/17               ES                W  45112100.0          4.0   3288261.39         L        45
# 3    29/12/17               ES                W  45112100.0          4.0   3288261.39         L        45
# 4    29/12/17               ES                W  45112100.0          4.0   3288261.39         L        45

# %%
ted_es.columns
# Out:
# Index(['DT_DISPATCH', 'ISO_COUNTRY_CODE', 'TYPE_OF_CONTRACT', 'CPV', 'LOTS_NUMBER', 'VALUE_EURO', 'CRIT_CODE', 'CPV_GROUP'], dtype='object')

# %%
# quitar filas sin importe
ted_es = ted_es.dropna(subset=["VALUE_EURO"])

# convertir fecha
ted_es["DT_DISPATCH"] = pd.to_datetime(ted_es["DT_DISPATCH"], errors="coerce")

# crear año
ted_es["YEAR"] = ted_es["DT_DISPATCH"].dt.year

ted_es.shape
# Out:
# /var/folders/tq/4_dpx3ks4bjbl01vpysvb12w0000gn/T/ipykernel_49213/3602409011.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   ted_es["DT_DISPATCH"] = pd.to_datetime(ted_es["DT_DISPATCH"], errors="coerce")
# (323375, 9)

# %%
ted_es["YEAR"].value_counts().sort_index()
# Out:
# YEAR
# 2017       67
# 2018    29604
# 2019    52484
# 2020    71319
# 2021    62386
# 2022    61005
# 2023    46510
# Name: count, dtype: int64

# %%
ted_es["VALUE_EURO"].describe(percentiles=[0.5, 0.9, 0.99])
# Out:
# count    3.233750e+05
# mean     2.413638e+07
# std      7.236132e+08
# min      1.000000e-02
# 50%      1.386840e+06
# 90%      4.892391e+07
# 99%      2.038252e+08
# max      4.083333e+11
# Name: VALUE_EURO, dtype: float64

# %%
ted_es["CPV_GROUP"].value_counts().head(10)
# Out:
# CPV_GROUP
# 33    57270
# 85    27030
# 50    21562
# 90    20109
# 60    19639
# 71    15165
# 15    13166
# 34    13031
# 72    12451
# 79    11913
# Name: count, dtype: int64

# %%
ted_es["TYPE_OF_CONTRACT"].value_counts()
# Out:
# TYPE_OF_CONTRACT
# S    161189
# U    155963
# W      6223
# Name: count, dtype: int64

# %%
ted_es.to_csv("../data/ted_es_clean.csv", index=False)

# %% [markdown]
# EDA – Public Procurement in Spain (TED)
# Overview
#
# This exploratory data analysis (EDA) analyses public procurement contract notices in Spain published in Tenders Electronic Daily (TED) for the period 2018–2023.
# The objective is to understand the volume, value and structure of public procurement as a first step towards machine learning models and analytical dashboards.
#
# Data Source
#
# Tenders Electronic Daily (TED) – European Commission
#
# Period: 2018–2023
#
# Country: Spain (ISO code: ES)
#
# Dataset Preparation
#
# Original dataset size: ~4 GB (raw TED data)
#
# Data processed locally using chunk-based reading
#
# Filtered to Spanish contracts only
#
# Basic cleaning applied:
#
# Removal of missing contract values
#
# Date parsing and year extraction
#
# CPV grouping at 2-digit level
#
# Final working dataset:
#
# 323,375 contracts
#
# 9 analytical variables
#
# Key Variables
#
# DT_DISPATCH – publication date
#
# YEAR – publication year
#
# TYPE_OF_CONTRACT – services, supplies, works
#
# CPV / CPV_GROUP – contract subject
#
# VALUE_EURO – contract value
#
# LOTS_NUMBER – number of lots
#
# CRIT_CODE – award criterion
#
# Key Findings
# Contract Volume by Year
#
# Stable and consistent coverage between 2018 and 2023
#
# 2017 records are residual and linked to data transitions
#
# Contract Value Distribution
#
# Median value: ~1.39 million EUR
#
# Highly right-skewed distribution
#
# Presence of very large contracts (expected in public procurement)
#
# Type of Contract
#
# Services (S): ~161,000 contracts
#
# Supplies (U): ~156,000 contracts
#
# Works (W): ~6,000 contracts
#
# Public procurement in Spain is dominated by services and supplies, while works are less frequent but typically higher in value.
#
# CPV Analysis (Top Groups)
#
# The most frequent CPV groups correspond to:
#
# Healthcare-related procurement
#
# Professional and technical services
#
# ICT and digital services
#
# Transport and infrastructure-related services
#
# These patterns are fully consistent with the structure of Spanish public procurement.
#
# Output
#
# A cleaned and reproducible analytical dataset has been generated and stored as:
#
# data/ted_es_clean.csv
#
#
# This dataset is ready for:
#
# Feature engineering
#
# Machine learning models
#
# Integration into BI dashboards (e.g. Power BI)
#
# Next Steps
#
# Definition of machine learning objectives
#
# Integration with national Spanish data (PCSP)
#
# Development of procurement indicators and dashboards

# %%
from xml.etree import ElementTree as ET

ATOM_PATH = "../data_raw/pcsp/2020/licitacionesPerfilesContratanteCompleto3_20200712_150726_1.atom"

tree = ET.parse(ATOM_PATH)
root = tree.getroot()

root.tag, len(root)
# Out:
# ('{http://www.w3.org/2005/Atom}feed', 508)

# %%
import os

os.listdir("../data_raw/pcsp/2020")
# Out:
# ['licitacionesPerfilesContratanteCompleto3_20200724_185726_7.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200715_212659_7.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201029_181628_2.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201111_003732_1.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201123_151929.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200724_002734_4.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201216_193011_1.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201004_162721_1.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200725_111919_4.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201008_183751.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200819_181328_1.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200716_181101_4.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200719_154945_3.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200721_183210.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200724_165651_2.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200725_155546_8.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201023_152058.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200724_223932_2.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201021_202312.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201219_150015.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201120_153134.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200819_151720_4.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201026_200117.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200818_192634_6.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200718_174535_9.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200718_234205_7.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200725_111919_10.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200725_130946_2.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200724_223932_10.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201117_151528_1.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200723_204346_1.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200721_183210_7.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200725_004241_3.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200721_225545_1.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201229_185029.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201124_210339_1.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200916_184312_1.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200724_002734_8.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201111_174224_1.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200725_111919_8.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201120_153134_1.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200716_181101_8.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200712_160000_5.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200720_163019_1.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200909_171536.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201013_151912.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200831_231844_3.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200725_155546_4.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200819_164309_2.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201209_150016_1.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201106_152351_1.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201018_143303_1.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200723_224451_3.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200831_214857_2.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200723_214700_2.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201227_150014.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200721_201058_5.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201203_211008.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201027_170013.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200718_174535_5.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200819_151720_8.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201026_200117_2.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201211_185658_2.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201005_152047.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201021_202312_1.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200718
1.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200725_130946_1.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200718_174535.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200718_234205_4.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201117_151528_2.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200720_163019.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201009_151632_1.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200723_204346_2.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200724_223932.atom']

# %%
import os
os.getcwd()
# Out:
# '/Users/mariamiura/procurement-project/notebooks'

# %%
import os
os.listdir("..")
# Out:
# ['.venv', 'data_raw', 'data', 'notebooks', 'src']

# %%
import os
os.listdir("../data_raw")
# Out:
# ['pcsp',
#  'e05188501-perfiles-de-contratante-de-los-organos-de-contratacion-alojados-en-la-plataforma-de-contratacion-del-sector-publico.csv',
#  'export_CFC_2018_2023.csv']

# %%
import os

os.listdir("../data_raw/pcsp/2020")[:5]
# Out:
# ['licitacionesPerfilesContratanteCompleto3_20200724_185726_7.atom',
#  'licitacionesPerfilesContratanteCompleto3_20200715_212659_7.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201029_181628_2.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201111_003732_1.atom',
#  'licitacionesPerfilesContratanteCompleto3_20201123_151929.atom']

# %%
from xml.etree import ElementTree as ET

ATOM_PATH = "../data_raw/pcsp/2020/licitacionesPerfilesContratanteCompleto3_20200724_185726_7.atom"

tree = ET.parse(ATOM_PATH)
root = tree.getroot()

ns = {"atom": "http://www.w3.org/2005/Atom"}

entry = root.find("atom:entry", ns)
title = entry.find("atom:title", ns)

print(title.text)
# Out:
# Obras para la sustitución de la red de tuberías generales de agua sanitaria y red de Bie`s en el Edificio "A" del Rectorado de la Universidad Politécnica de Madrid.

# %%
# fecha de publicación
published = entry.find("atom:published", ns)
published.text if published is not None else None

# %%
# buscar CPV dentro del contenido
content = entry.find("atom:content", ns)

cpvs = []
if content is not None:
    for el in content.iter():
        if el.tag.lower().endswith("cpv"):
            cpvs.append(el.text)

cpvs[:5]
# Out:
# []

# %%
published = entry.find("atom:published", ns)
print("published:", published.text if published is not None else None)
# Out:
# published: None

# %%
content = entry.find("atom:content", ns)

if content is None:
    print("❌ No existe atom:content en este entry")
    print("Tags hijos disponibles:")
    for el in list(entry)[:20]:
        print(el.tag)
else:
    for el in list(content.iter())[:20]:
        print(el.tag)
# Out:
# ❌ No existe atom:content en este entry
# Tags hijos disponibles:
# {http://www.w3.org/2005/Atom}id
# {http://www.w3.org/2005/Atom}link
# {http://www.w3.org/2005/Atom}summary
# {http://www.w3.org/2005/Atom}title
# {http://www.w3.org/2005/Atom}updated
# {urn:dgpe:names:draft:codice-place-ext:schema:xsd:CommonAggregateComponents-2}ContractFolderStatus

# %%
for el in entry:
    print(el.tag)
# Out:
# {http://www.w3.org/2005/Atom}id
# {http://www.w3.org/2005/Atom}link
# {http://www.w3.org/2005/Atom}summary
# {http://www.w3.org/2005/Atom}title
# {http://www.w3.org/2005/Atom}updated
# {urn:dgpe:names:draft:codice-place-ext:schema:xsd:CommonAggregateComponents-2}ContractFolderStatus

# %%
updated = entry.find("atom:updated", ns)
print("updated:", updated.text if updated is not None else None)
# Out:
# updated: 2020-06-02T18:16:14.472+02:00

# %%
cfs = entry.find("{urn:dgpe:names:draft:codice-place-ext:schema:xsd:CommonAggregateComponents-2}ContractFolderStatus")

cpvs = []
for el in cfs.iter():
    tag = el.tag.lower()
    if "cpv" in tag and el.text:
        cpvs.append(el.text.strip())

print("CPVs found (first 10):", cpvs[:10])
# Out:
# CPVs found (first 10): []

# %%
cfs = entry.find("{urn:dgpe:names:draft:codice-place-ext:schema:xsd:CommonAggregateComponents-2}ContractFolderStatus")

# imprime tags "candidatas" (clasificación / item / commodity / classification)
candidates = []
for el in cfs.iter():
    t = el.tag
    tl = t.lower()
    if any(k in tl for k in ["class", "commodity", "item", "code", "cpv", "main", "additional"]):
        candidates.append(t)

# muestra únicas y las primeras 60
uniq = list(dict.fromkeys(candidates))
print("\n".join(uniq[:60]))
# Out:
# {urn:dgpe:names:draft:codice-place-ext:schema:xsd:CommonBasicComponents-2}ContractFolderStatusCode
# {urn:dgpe:names:draft:codice:schema:xsd:CommonBasicComponents-2}ContractingPartyTypeCode
# {urn:dgpe:names:draft:codice:schema:xsd:CommonBasicComponents-2}IdentificationCode
# {urn:dgpe:names:draft:codice:schema:xsd:CommonBasicComponents-2}TypeCode
# {urn:dgpe:names:draft:codice:schema:xsd:CommonBasicComponents-2}SubTypeCode
# {urn:dgpe:names:draft:codice:schema:xsd:CommonAggregateComponents-2}RequiredCommodityClassification
# {urn:dgpe:names:draft:codice:schema:xsd:CommonBasicComponents-2}ItemClassificationCode
# {urn:dgpe:names:draft:codice:schema:xsd:CommonBasicComponents-2}CountrySubentityCode
# {urn:dgpe:names:draft:codice:schema:xsd:CommonBasicComponents-2}GuaranteeTypeCode
# {urn:dgpe:names:draft:codice:schema:xsd:CommonBasicComponents-2}EvaluationCriteriaTypeCode
# {urn:dgpe:names:draft:codice:schema:xsd:CommonBasicComponents-2}RequirementTypeCode
# {urn:dgpe:names:draft:codice:schema:xsd:CommonBasicComponents-2}ProcedureCode
# {urn:dgpe:names:draft:codice:schema:xsd:CommonBasicComponents-2}UrgencyCode
# {urn:dgpe:names:draft:codice:schema:xsd:CommonBasicComponents-2}SubmissionMethodCode
# {urn:dgpe:names:draft:codice-place-ext:schema:xsd:CommonBasicComponents-2}NoticeTypeCode
# {urn:dgpe:names:draft:codice-place-ext:schema:xsd:CommonAggregateComponents-2}AdditionalPublicationStatus
# {urn:dgpe:names:draft:codice-place-ext:schema:xsd:CommonAggregateComponents-2}AdditionalPublicationDocumentReference

# %%
# namespace de CODICE (donde está ItemClassificationCode)
NS_CODICE_CBC = "urn:dgpe:names:draft:codice:schema:xsd:CommonBasicComponents-2"
NS_CODICE_CAC = "urn:dgpe:names:draft:codice:schema:xsd:CommonAggregateComponents-2"

cpvs = []

for req in cfs.iter(f"{{{NS_CODICE_CAC}}}RequiredCommodityClassification"):
    code_el = req.find(f".//{{{NS_CODICE_CBC}}}ItemClassificationCode")
    if code_el is not None and code_el.text:
        cpvs.append(code_el.text.strip())

print("CPVs:", cpvs)
# Out:
# CPVs: ['45332000']

# %%
import pandas as pd

row = {
    "title": title.text if title is not None else None,
    "updated": updated.text if updated is not None else None,
    "cpv": cpvs[0] if len(cpvs) else None
}

df_one = pd.DataFrame([row])
df_one
# Out:
#                                                title                        updated       cpv
# 0  Obras para la sustitución de la red de tubería...  2020-06-02T18:16:14.472+02:00  45332000

# %%
def parse_atom_file(path):
    return {
        "title": ...,
        "date": ...,
        "cpv": ...
    }

# %%
import os

PCSP_DIR = "../data_raw/pcsp/2020"
files = sorted([f for f in os.listdir(PCSP_DIR) if f.endswith(".atom")])[:50]
len(files), files[:3]
# Out:
# (50,
#  ['licitacionesPerfilesContratanteCompleto3.atom',
#   'licitacionesPerfilesContratanteCompleto3_20200712_150726.atom',
#   'licitacionesPerfilesContratanteCompleto3_20200712_150726_1.atom'])

# %%
rows = []
for f in files:
    path = os.path.join(PCSP_DIR, f)
    rows.append(parse_atom_file(path))

import pandas as pd
df_pcsp = pd.DataFrame(rows)
df_pcsp.head()
# Out:
#       title      date       cpv
# 0  Ellipsis  Ellipsis  Ellipsis
# 1  Ellipsis  Ellipsis  Ellipsis
# 2  Ellipsis  Ellipsis  Ellipsis
# 3  Ellipsis  Ellipsis  Ellipsis
# 4  Ellipsis  Ellipsis  Ellipsis

# %%
from xml.etree import ElementTree as ET

NS_ATOM = {"atom": "http://www.w3.org/2005/Atom"}
NS_CODICE_CBC = "urn:dgpe:names:draft:codice:schema:xsd:CommonBasicComponents-2"
NS_CODICE_CAC = "urn:dgpe:names:draft:codice:schema:xsd:CommonAggregateComponents-2"

def parse_atom_file(path):
    tree = ET.parse(path)
    root = tree.getroot()

    entry = root.find("atom:entry", NS_ATOM)
    if entry is None:
        return {"title": None, "date": None, "cpv": None}

    # title
    title_el = entry.find("atom:title", NS_ATOM)
    title = title_el.text if title_el is not None else None

    # date (updated)
    updated_el = entry.find("atom:updated", NS_ATOM)
    date = updated_el.text if updated_el is not None else None

    # CPV
    cpv = None
    cfs = entry.find(f"{{{NS_CODICE_CAC}}}ContractFolderStatus")
    if cfs is not None:
        for req in cfs.iter(f"{{{NS_CODICE_CAC}}}RequiredCommodityClassification"):
            code_el = req.find(f".//{{{NS_CODICE_CBC}}}ItemClassificationCode")
            if code_el is not None and code_el.text:
                cpv = code_el.text.strip()
                break

    return {
        "title": title,
        "date": date,
        "cpv": cpv
    }

# %%
rows = []
for f in files:
    rows.append(parse_atom_file(os.path.join(PCSP_DIR, f)))

df_pcsp = pd.DataFrame(rows)
df_pcsp.head()
# Out:
#                                                title                           date   cpv
# 0  Servicio de recepción, apertura y cierre, cont...  2020-12-31T21:24:54.624+01:00  None
# 1  Obras de construcción e instalación de un cent...  2020-01-03T13:04:28.942+01:00  None
# 2  Adquisición de simuladores de I&A para Pizarro...  2020-01-02T14:00:40.564+01:00  None
# 3  Servicios asistencia técnica estrategia DUSI "...  2020-01-02T09:29:29.747+01:00  None
# 4  Contratación con entidad especializada de los ...  2020-01-10T13:20:42.428+01:00  None

# %%
test_path = os.path.join(PCSP_DIR, files[0])

from xml.etree import ElementTree as ET
tree = ET.parse(test_path)
root = tree.getroot()

ns = {"atom": "http://www.w3.org/2005/Atom"}
entry = root.find("atom:entry", ns)

# encuentra ContractFolderStatus (si existe)
cfs = None
for el in entry:
    if el.tag.endswith("ContractFolderStatus"):
        cfs = el
        break

print("Has ContractFolderStatus:", cfs is not None)

# imprime las primeras 80 etiquetas internas que contengan "Classification" o "Item"
hits = []
if cfs is not None:
    for el in cfs.iter():
        tl = el.tag.lower()
        if "classification" in tl or "item" in tl or "commodity" in tl or "cpv" in tl:
            hits.append(el.tag)

# muestra únicas
uniq = list(dict.fromkeys(hits))
print("\n".join(uniq[:80]))
# Out:
# Has ContractFolderStatus: True
# {urn:dgpe:names:draft:codice:schema:xsd:CommonAggregateComponents-2}RequiredCommodityClassification
# {urn:dgpe:names:draft:codice:schema:xsd:CommonBasicComponents-2}ItemClassificationCode

# %%
NS_CBC = "urn:dgpe:names:draft:codice:schema:xsd:CommonBasicComponents-2"
NS_CAC = "urn:dgpe:names:draft:codice:schema:xsd:CommonAggregateComponents-2"

# coge el primer ItemClassificationCode que aparezca y muestra texto + atributos
code_el = cfs.find(f".//{{{NS_CBC}}}ItemClassificationCode")
print("text:", code_el.text)
print("attrib:", code_el.attrib)
# Out:
# text: 79992000
# attrib: {'listURI': 'http://contrataciondelestado.es/codice/cl/1.04/CPV2007-1.04.gc'}

# %%
from xml.etree import ElementTree as ET

NS_ATOM = {"atom": "http://www.w3.org/2005/Atom"}
NS_CBC = "urn:dgpe:names:draft:codice:schema:xsd:CommonBasicComponents-2"
NS_CAC = "urn:dgpe:names:draft:codice:schema:xsd:CommonAggregateComponents-2"

def parse_atom_file(path):
    tree = ET.parse(path)
    root = tree.getroot()

    entry = root.find("atom:entry", NS_ATOM)
    if entry is None:
        return {"title": None, "date": None, "cpv": None}

    title_el = entry.find("atom:title", NS_ATOM)
    title = title_el.text if title_el is not None else None

    updated_el = entry.find("atom:updated", NS_ATOM)
    date = updated_el.text if updated_el is not None else None

    cpv = None
    cfs = entry.find(f"{{{NS_CAC}}}ContractFolderStatus")
    if cfs is not None:
        code_el = cfs.find(f".//{{{NS_CBC}}}ItemClassificationCode")
        if code_el is not None and code_el.text:
            cpv = code_el.text.strip()

    return {"title": title, "date": date, "cpv": cpv}

# %%
rows = [parse_atom_file(os.path.join(PCSP_DIR, f)) for f in files]
df_pcsp = pd.DataFrame(rows)
df_pcsp.head()
# Out:
#                                                title                           date   cpv
# 0  Servicio de recepción, apertura y cierre, cont...  2020-12-31T21:24:54.624+01:00  None
# 1  Obras de construcción e instalación de un cent...  2020-01-03T13:04:28.942+01:00  None
# 2  Adquisición de simuladores de I&A para Pizarro...  2020-01-02T14:00:40.564+01:00  None
# 3  Servicios asistencia técnica estrategia DUSI "...  2020-01-02T09:29:29.747+01:00  None
# 4  Contratación con entidad especializada de los ...  2020-01-10T13:20:42.428+01:00  None

# %%
cpv_values = []

for f in files:
    row = parse_atom_file(os.path.join(PCSP_DIR, f))
    if row["cpv"] is not None:
        cpv_values.append(row["cpv"])

print("CPVs encontrados:", len(cpv_values))
print("Ejemplos:", cpv_values[:5])
# Out:
# CPVs encontrados: 0
# Ejemplos: []

# %%
df_pcsp["year"] = df_pcsp["date"].str[:4]
df_pcsp.to_csv("../data/pcsp_2020_sample.csv", index=False)

print("Saved:", df_pcsp.shape)
# Out:
# Saved: (50, 4)

# %%
print("test")
# Out:
# test

# %%
1+1
# Out:
# 2

# %%
1+1
# Out:
# 2

# %%
import time
print("antes")
time.sleep(2)
print("después")
# Out:
# antes
# después

# %%
print("funciona")
# Out:
# funciona

# %%
df_pcsp.to_csv("../data/pcsp_2020_sample.csv", index=False)
print("Guardado")
# Out:
# Guardado

# %%
import os
os.path.exists("../data/pcsp_2020_sample.csv")
# Out:
# True

# %%
import pandas as pd

df = pd.read_csv("../data/pcsp_2020_sample.csv")
df.head()
# Out:
#                                                title                           date  cpv  year
# 0  Servicio de recepción, apertura y cierre, cont...  2020-12-31T21:24:54.624+01:00  NaN  2020
# 1  Obras de construcción e instalación de un cent...  2020-01-03T13:04:28.942+01:00  NaN  2020
# 2  Adquisición de simuladores de I&A para Pizarro...  2020-01-02T14:00:40.564+01:00  NaN  2020
# 3  Servicios asistencia técnica estrategia DUSI "...  2020-01-02T09:29:29.747+01:00  NaN  2020
# 4  Contratación con entidad especializada de los ...  2020-01-10T13:20:42.428+01:00  NaN  2020

# %%
df.info
# Out:
# <bound method DataFrame.info of                                                 title                           date  cpv  year
# 0   Servicio de recepción, apertura y cierre, cont...  2020-12-31T21:24:54.624+01:00  NaN  2020
# 1   Obras de construcción e instalación de un cent...  2020-01-03T13:04:28.942+01:00  NaN  2020
# 2   Adquisición de simuladores de I&A para Pizarro...  2020-01-02T14:00:40.564+01:00  NaN  2020
# 3   Servicios asistencia técnica estrategia DUSI "...  2020-01-02T09:29:29.747+01:00  NaN  2020
# 4   Contratación con entidad especializada de los ...  2020-01-10T13:20:42.428+01:00  NaN  2020
# 5   Servicio desplazamiento viajeros entre l'ametl...  2020-01-10T09:43:25.343+01:00  NaN  2020
# 6   Gestión integral de las instalaciones deportiv...  2020-01-09T13:53:18.708+01:00  NaN  2020
# 7   Suministro de equip., software, instalación, f...  2020-01-09T09:32:27.177+01:00  NaN  2020
# 8   FLOSUB.- (T.A. 2020) Contrato de servicios par...  2020-01-08T13:06:33.308+01:00  NaN  2020
# 9   contrato fiestas locales patronales 2020 san i...  2020-01-08T00:02:55.171+01:00  NaN  2020
# 10  Servicio de maquinaria pesada del Plan Infocam...  2020-01-07T10:04:37.709+01:00  NaN  2020
# 11  Contratación del servicio de vigilancia y segu...  2020-01-17T13:16:48.582+01:00  NaN  2020
# 12  Adecuación Infraestructuras viales del polígon...  2020-01-17T09:19:42.356+01:00  NaN  2020
# 13  Contratación del servicio de la vigilancia de ...  2020-01-16T13:42:44.437+01:00  NaN  2020
# 44                                              Gases  2020-02-05T11:57:17.461+01:00  NaN  2020
# 45  Servicio de dirección de obras promovidas por ...  2020-02-04T17:31:25.799+01:00  NaN  2020
# 46  Servicio de Asistencia Sanitaria Ambulatoria,E...  2020-02-04T12:02:47.420+01:00  NaN  2020
# 47  Servicio de agencia de noticias de contenidos ...  2020-02-03T16:09:16.048+01:00  NaN  2020
# 48  Contratación de un servicio de inspección de i...  2020-02-03T10:56:54.409+01:00  NaN  2020
# 49  Varias dependencias.-Servicio Abierto de Mante...  2020-02-14T13:33:20.812+01:00  NaN  2020>

# %%
df.describe(include="all")
# Out:
#                                                     title                           date  cpv    year
# count                                                  50                             50  0.0    50.0
# unique                                                 50                             50  NaN     NaN
# top     Servicio de recepción, apertura y cierre, cont...  2020-12-31T21:24:54.624+01:00  NaN     NaN
# freq                                                    1                              1  NaN     NaN
# mean                                                  NaN                            NaN  NaN  2020.0
# std                                                   NaN                            NaN  NaN     0.0
# min                                                   NaN                            NaN  NaN  2020.0
# 25%                                                   NaN                            NaN  NaN  2020.0
# 50%                                                   NaN                            NaN  NaN  2020.0
# 75%                                                   NaN                            NaN  NaN  2020.0
# max                                                   NaN                            NaN  NaN  2020.0

# %%
import pandas as pd

PATH_TED = "../data_raw/export_CFC_2018_2023.csv"

usecols = ["YEAR", "ISO_COUNTRY_CODE", "TYPE_OF_CONTRACT", "CPV", "VALUE_EURO"]

chunks = pd.read_csv(PATH_TED, usecols=usecols, chunksize=300_000, low_memory=False)

parts = []
for ch in chunks:
    ch = ch[(ch["YEAR"] == 2020) & (ch["ISO_COUNTRY_CODE"] == "ES")]
    if len(ch):
        parts.append(ch)

ted_2020_es = pd.concat(parts, ignore_index=True)
print("TED 2020 ES shape:", ted_2020_es.shape)
ted_2020_es.head()
# Out:
# TED 2020 ES shape: (78431, 5)
#    YEAR ISO_COUNTRY_CODE TYPE_OF_CONTRACT         CPV    VALUE_EURO
# 0  2020               ES                W  45212312.0  1.453714e+07
# 1  2020               ES                W  45233000.0  1.038603e+07
# 2  2020               ES                W  45233000.0  1.275294e+07
# 3  2020               ES                W  45233000.0  2.076676e+07
# 4  2020               ES                W  45233120.0  1.156429e+08

# %%
import pandas as pd

pcsp_2020 = pd.read_csv("../data/pcsp_2020_sample.csv")

print("PCSP 2020 sample shape:", pcsp_2020.shape)
pcsp_2020.head()
# Out:
# PCSP 2020 sample shape: (50, 4)
#                                                title  \
# 0  Servicio de recepción, apertura y cierre, cont...
# 1  Obras de construcción e instalación de un cent...
# 2  Adquisición de simuladores de I&A para Pizarro...
# 3  Servicios asistencia técnica estrategia DUSI "...
# 4  Contratación con entidad especializada de los ...
#
#                             date  cpv  year
# 0  2020-12-31T21:24:54.624+01:00  NaN  2020
# 1  2020-01-03T13:04:28.942+01:00  NaN  2020
# 2  2020-01-02T14:00:40.564+01:00  NaN  2020
# 3  2020-01-02T09:29:29.747+01:00  NaN  2020
# 4  2020-01-10T13:20:42.428+01:00  NaN  2020
